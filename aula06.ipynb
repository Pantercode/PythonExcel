# %%
import pandas as pd

# %%
data = {
    'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Ana'],
    'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti','Schimtts','Hoffam'],
    'Idade Atual': [31, 31, 25, 35, 22, 21, 28, 20],
}

df = pd.DataFrame(data)

# %%
# adicionando linhas
df.loc[len(df)] = ['Robearta','de Souza',23]
df
# Out:
#        Nome   Sobrenome  Idade Atual
# 0   Adriano      Soares           31
# 1   Rodrigo    Tadewald           31
# 2   Juliano    Faccioni           25
# 3    Mateus     Kienzle           35
# 4     Luiza   Cherobini           22
# 5   Rodrigo  Vanzelotti           21
# 6     Ayres    Schimtts           28
# 7       Ana      Hoffam           20
# 8  Robearta    de Souza           23

# %%
# adicionando linhas
df.loc[9] = ['Marcell','Oliveira', '35']
df
# Out:
#        Nome   Sobrenome Idade Atual
# 0   Adriano      Soares          31
# 1   Rodrigo    Tadewald          31
# 2   Juliano    Faccioni          25
# 3    Mateus     Kienzle          35
# 4     Luiza   Cherobini          22
# 5   Rodrigo  Vanzelotti          21
# 6     Ayres    Schimtts          28
# 7       Ana      Hoffam          20
# 8  Robearta    de Souza          23
# 9   Marcell    Oliveira          35

# %%
data2  =  {'Nome':['Marcelle'],
            'Sobrenome':['Oliveira'],
            'Idade Atual':[1]}
df2 = pd.DataFrame(data2)
df2
# Out:
#        Nome Sobrenome  Idade Atual
# 0  Marcelle  Oliveira            1

# %%
df_uniao  = pd.concat([df,df2])
df_uniao
# Out:
#        Nome   Sobrenome Idade Atual
# 0   Adriano      Soares          31
# 1   Rodrigo    Tadewald          31
# 2   Juliano    Faccioni          25
# 3    Mateus     Kienzle          35
# 4     Luiza   Cherobini          22
# 5   Rodrigo  Vanzelotti          21
# 6     Ayres    Schimtts          28
# 7       Ana      Hoffam          20
# 8  Robearta    de Souza          23
# 9   Marcell    Oliveira          35
# 0  Marcelle    Oliveira           1
