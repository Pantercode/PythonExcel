# %%
import pandas as pd

# %%
data = {
    'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Ana'],
    'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti','Schimtts','Hoffam'],
    'Idade Atual': [31, 31, 25, 35, 22, 21, 28, 20],
}

df = pd.DataFrame(data)

# %%
df['Qualidade'] = 'sim'
df
# Out:
#       Nome   Sobrenome  Idade Atual Qualidade
# 0  Adriano      Soares           31       sim
# 1  Rodrigo    Tadewald           31       sim
# 2  Juliano    Faccioni           25       sim
# 3   Mateus     Kienzle           35       sim
# 4    Luiza   Cherobini           22       sim
# 5  Rodrigo  Vanzelotti           21       sim
# 6    Ayres    Schimtts           28       sim
# 7      Ana      Hoffam           20       sim

# %%
df['Cidade'] = ['Lajeado','Porto Alegre', 'Lajeado','Porto Alegre','Porto Alegre','Porto Alegre','Porto Alegre','Porto Alegre']
df
# Out:
#       Nome   Sobrenome  Idade Atual Qualidade        Cidade
# 0  Adriano      Soares           31       sim       Lajeado
# 1  Rodrigo    Tadewald           31       sim  Porto Alegre
# 2  Juliano    Faccioni           25       sim       Lajeado
# 3   Mateus     Kienzle           35       sim  Porto Alegre
# 4    Luiza   Cherobini           22       sim  Porto Alegre
# 5  Rodrigo  Vanzelotti           21       sim  Porto Alegre
# 6    Ayres    Schimtts           28       sim  Porto Alegre
# 7      Ana      Hoffam           20       sim  Porto Alegre

# %%
df.insert(3, 'Signo',['Leao','Aries','Peixes','Sagitario','Capricornio','Aries','Peixes','Sagitario'])
df
# Out:
#       Nome   Sobrenome  Idade Atual        Signo Qualidade        Cidade
# 0  Adriano      Soares           31         Leao       sim       Lajeado
# 1  Rodrigo    Tadewald           31        Aries       sim  Porto Alegre
# 2  Juliano    Faccioni           25       Peixes       sim       Lajeado
# 3   Mateus     Kienzle           35    Sagitario       sim  Porto Alegre
# 4    Luiza   Cherobini           22  Capricornio       sim  Porto Alegre
# 5  Rodrigo  Vanzelotti           21        Aries       sim  Porto Alegre
# 6    Ayres    Schimtts           28       Peixes       sim  Porto Alegre
# 7      Ana      Hoffam           20    Sagitario       sim  Porto Alegre

# %%
df['Dobro idade'] = df['Idade Atual'] * 2
df
# Out:
#       Nome   Sobrenome  Idade Atual        Signo Qualidade        Cidade  \
# 0  Adriano      Soares           31         Leao       sim       Lajeado
# 1  Rodrigo    Tadewald           31        Aries       sim  Porto Alegre
# 2  Juliano    Faccioni           25       Peixes       sim       Lajeado
# 3   Mateus     Kienzle           35    Sagitario       sim  Porto Alegre
# 4    Luiza   Cherobini           22  Capricornio       sim  Porto Alegre
# 5  Rodrigo  Vanzelotti           21        Aries       sim  Porto Alegre
# 6    Ayres    Schimtts           28       Peixes       sim  Porto Alegre
# 7      Ana      Hoffam           20    Sagitario       sim  Porto Alegre
#
#    Dobro idade
# 0           62
# 1           62
# 2           50
# 3           70
# 4           44
# 5           42
# 6           56
# 7           40

# %%
df['Quadrado idade'] = df['Idade Atual'] * df['Idade Atual']
df
# Out:
#       Nome   Sobrenome  Idade Atual        Signo Qualidade        Cidade  \
# 0  Adriano      Soares           31         Leao       sim       Lajeado
# 1  Rodrigo    Tadewald           31        Aries       sim  Porto Alegre
# 2  Juliano    Faccioni           25       Peixes       sim       Lajeado
# 3   Mateus     Kienzle           35    Sagitario       sim  Porto Alegre
# 4    Luiza   Cherobini           22  Capricornio       sim  Porto Alegre
# 5  Rodrigo  Vanzelotti           21        Aries       sim  Porto Alegre
# 6    Ayres    Schimtts           28       Peixes       sim  Porto Alegre
# 7      Ana      Hoffam           20    Sagitario       sim  Porto Alegre
#
#    Dobro idade  Quadrado idade
# 0           62             961
# 1           62             961
# 2           50             625
# 3           70            1225
# 4           44             484
# 5           42             441
# 6           56             784
# 7           40             400

# %%
df['Nome completo'] = df['Nome'] + ' ' + df['Sobrenome']
df
# Out:
#       Nome   Sobrenome  Idade Atual        Signo Qualidade        Cidade  \
# 0  Adriano      Soares           31         Leao       sim       Lajeado
# 1  Rodrigo    Tadewald           31        Aries       sim  Porto Alegre
# 2  Juliano    Faccioni           25       Peixes       sim       Lajeado
# 3   Mateus     Kienzle           35    Sagitario       sim  Porto Alegre
# 4    Luiza   Cherobini           22  Capricornio       sim  Porto Alegre
# 5  Rodrigo  Vanzelotti           21        Aries       sim  Porto Alegre
# 6    Ayres    Schimtts           28       Peixes       sim  Porto Alegre
# 7      Ana      Hoffam           20    Sagitario       sim  Porto Alegre
#
#    Dobro idade  Quadrado idade       Nome completo
# 0           62             961      Adriano Soares
# 1           62             961    Rodrigo Tadewald
# 2           50             625    Juliano Faccioni
# 3           70            1225      Mateus Kienzle
# 4           44             484     Luiza Cherobini
# ...
